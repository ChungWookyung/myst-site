# %% [markdown]
# ---
# title: テンプレ
# date: 2025-01-29
# description: 説明文を書く
# keywords: キーワード１
# authors:
#     - name: 鄭　宇景
#       affiliations:
#         - 関東学園大学
# license: CC-BY-4.0
# open_access: true
# ---

# %%
using Plots

x = 1:0.1:10
y = sin.(x)
plot(x,y)
